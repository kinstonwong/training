# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Kinston**
# Semiconductor Process Engineer/Surface Lab Scientist

# %% [markdown]
# *I am interested in data science because human and machine thinks very differently, and I think this kind of diversity will help use to gain more insights*

# %% [markdown]
# ### Code for displaying the meaning of life

# %%
print("42")
# Out:
# 42

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Tip:</b> Now it is time for more memes”.
# </div>
#
# ![ICHC.jpg](attachment:33b4e680-eae0-4983-beba-cdd98d9cfce4.jpg)
#
# [Know more about this memes](https://knowyourmeme.com/memes/sites/cheezburger)
